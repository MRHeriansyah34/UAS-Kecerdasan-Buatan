# %%
from google.colab import drive
drive.mount('/content/drives/')
# Out:
# Drive already mounted at /content/drives/; to attempt to forcibly remount, call drive.mount("/content/drives/", force_remount=True).

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread('//content/drives/MyDrive/Pejabat.jpg', cv2.IMREAD_UNCHANGED)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=900x1600 at 0x7F5D0BF3D9D0>

# %%
print(img.shape)
# Out:
# (1600, 900, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
img=cv2.imread('//content/drives/MyDrive/Pejabat.jpg', cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=900x1600 at 0x7F5D0B66BCD0>

# %%
print(img.shape)
# Out:
# (1600, 900)

# %%
cv2.imwrite('/content/drives/MyDrive/Pejabatgrayscale.jpg',img)
# Out:
# True
